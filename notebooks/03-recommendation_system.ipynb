# %% [markdown]
# ### Recommendation Table

# %%
import pandas as pd
import numpy as np

# %%
final_similarity_matrix = pd.read_parquet('../data/final_item_similarity_matrix_sample.parquet')

# %%
user_item_matrix = pd.read_parquet('../data/user_item_matrix_sample.parquet')
book_df = pd.read_parquet('../data/book_eng.parquet')

# %%
final_similarity_matrix.columns = final_similarity_matrix.columns.astype('str')
final_similarity_matrix.index = final_similarity_matrix.index.astype('str')

# %%
import sys
sys.path.append('../')  # Adjust the path to point to the directory containing 'modules'

from modules.helper.PredictRating import PredictRating

pr = PredictRating()
filled_matrix = pr.fill_user_item_matrix_nonparallel(user_item_matrix, final_similarity_matrix)

# %%
filled_matrix
# Out:
# book_id   1080513   1375925   1646536   1690826   1843325   2115046   2238834  \
# ID
# 1045     3.186443  2.642372  2.961556  2.823744  2.978432        -1  2.876199
# 10560    1.553623  1.459493  1.809493  1.636258   1.69987  1.733709  1.506402
# 10857    1.743022  1.453515  1.764827  1.814362  1.768724  1.583014  1.424158
# 1326     1.637798        -1  1.477128  1.419772  1.712613  1.585423  1.578166
# 1327     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 1455     3.186443  2.642372  2.961556  2.823744  2.978432        -1  2.876199
# 1784     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 1829     1.063257   1.05211  1.002815  1.033495  1.086053   1.15048        -1
# 192       2.08142   1.97799  2.205229  2.180765  2.050596  2.022203  1.984606
# 201      2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 2282     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 2828     1.911866  1.585423  1.776934  1.694246  1.787059        -1  1.725719
# 284            -1  0.545933  0.563372  0.583664  0.648168  0.637289  0.531628
# 3017     2.253489  1.969504        -1  2.034626  2.274456  2.369245  2.005631
# 3203     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 3259           -1  1.091865  1.126744  1.167328  1.296336  1.274577  1.063257
# 3286     1.637798        -1  1.477128  1.419772  1.712613  1.585423  1.578166
# 3474     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 3625     4.128234        -1  3.675345  3.613191        -1  3.900956    3.7333
# 3628     2.857444  2.423642        -1        -1  2.852616  2.906431  2.537719
# 4489     2.071497  1.945991  2.412657  2.181677  2.266493  2.311612  2.008536
# 4534           -1  2.183731  2.253489  2.334655  2.592671  2.549155  2.126513
# 4567     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 464            -1  1.637798  1.690117  1.750991  1.944503  1.911866  1.594885
# 4806     2.183731        -1  1.969504  1.893029  2.283484  2.113897  2.104221
# 4852     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 4878     1.583039   1.38517  1.684027  1.605645  1.783152  1.578714  1.723625
# 5111     2.183731        -1  1.969504  1.893029  2.283484  2.113897  2.104221
# 5192     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 5527     2.729663        -1  2.461879  2.366287  2.854355  2.642372  2.630276
# 5869           -1  1.091865  1.126744  1.167328  1.296336  1.274577  1.063257
# 678            -1  2.729663  2.816861  2.918319  3.240839  3.186443  2.658142
# 6845     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
# 7268           -1  1.091865  1.126744  1.167328  1.296336  1.274577  1.063257
# 7396     1.911866  1.585423  1.776934  1.694246  1.787059        -1  1.725719
# 7410     2.729663        -1  2.461879  2.366287  2.854355  2.642372  2.630276
# 7424     2.549155  2.113897  2.369245  2.258995  2.382746        -1  2.300959
#
# 7600      0.52768  0.520355  0.626283  0.581007  0.517874
# 768      2.006322  2.391864        -1  2.419744  2.121702
# 7742     2.631191  2.527754  3.202839  2.638356  2.889515
# 7802     2.631191  2.527754  3.202839  2.638356  2.889515
# 8241           -1  1.435636  1.504742  1.502304  1.755021
# 8431     2.104953  2.022203  2.562272  2.110685  2.311612
# 853      1.578714  1.516652  1.921704  1.583014  1.733709
# 855      2.104953  2.022203  2.562272  2.110685  2.311612
# 8635     2.104953  2.022203  2.562272  2.110685  2.311612
# 8686     2.104953  2.022203  2.562272  2.110685  2.311612
# 9545     1.003161  1.195932        -1  1.209872  1.060851
# 9547     1.578714  1.516652  1.921704  1.583014  1.733709
# 9642     2.104953  2.022203  2.562272  2.110685  2.311612

# %%
filled_matrix.T.loc[:, '1045'].sort_values(ascending = False)[:10]
# Out:
# book_id
# 776434     3.202839
# 1080513    3.186443
# 1843325    2.978432
# 1646536    2.961556
# 920766     2.889515
# 2238834    2.876199
# 1690826    2.823744
# 1375925    2.642372
# 849880     2.638356
# 2993119    2.631191
# Name: 1045, dtype: object

# %%
user_id_list = []
book_metadata_title_list = []
book_metadata_description_list = []
book_metadata_id_list = []
for user_id in filled_matrix.index:
    book_metadata_id = filled_matrix.T[user_id].sort_values(ascending = False)[:10].index.tolist()
    book_metadata_id_list.extend(book_metadata_id)
    user_id_list.extend([user_id]*len(book_metadata_id))
    for book_id in book_metadata_id:
        book_metadata_title_list.append(book_df[book_df['Id']==int(book_id)]['Name'].values[0])
        book_metadata_description_list.append(book_df[book_df['Id']==int(book_id)]['Description'].values[0])

top_k_recommendations_df = pd.DataFrame({
    'user_id': user_id_list, 
    'book_id': book_metadata_id_list, 
    'book_title': book_metadata_title_list, 
    'description': book_metadata_description_list
    })

# %%
top_k_recommendations_df
# Out:
#     user_id  book_id                                         book_title  \
# 0      1045   776434                        Wild Cards (Wild Cards, #1)
# 1      1045  1080513  Incubus Dreams (Anita Blake, Vampire Hunter, #12)
# 2      1045  1843325         Evil Breeding (A Dog Lover's Mystery, #12)
# 3      1045  1646536                               The Sound of Thunder
# 4      1045   920766                                       The Vagrants
# ..      ...      ...                                                ...
# 505    9642  2238834     Love and Biology at the Center of the Universe
# 506    9642  1690826                                             Lilith
# 507    9642  1375925   The Unexpected Mrs. Pollifax (Mrs. Pollifax, #1)
# 508    9642   849880                                      Hell's Angels
# 509    9642  2993119                                The Reasons of Love
#
#                                            description
# 0    A shared-universe superhero prose anthology ed...
# 1    As consultant to the Regional Preternatural Cr...
# 2    When dog writer Holly Winter receives her firs...
# 3    <i>The Sound of Thunder</i>, a Courtney Family...
# 4    Brilliant and illuminating, this astonishing d...
# ..                                                 ...
# 505  When she learns that her college sweetheart hu...
# 506  First Ballantine Adult Fantasy Edition, 1969<b...
# 507  Mrs. Virgil (Emily) Pollifax of New Brunswick,...
# 508  "California, Labor Day weekend...early, with o...
# 509  This beautifully written book by one of the wo...
#
# [510 rows x 4 columns]
